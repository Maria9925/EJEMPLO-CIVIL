# %% [markdown]
# # Module 1: Fluid properties

# %%
pip install -r requirements.txt
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.

# %%
import handcalcs.render
from sympy import symbols, Eq, solve
from math import sqrt,pi, cos, sin, radians,asin,atan,degrees, tan, log10
from PIL import Image

# %% [markdown]
# Global variables:

# %%
# %%render param
# g=9.81 #m/s2
# rho_water=1000 #kg/m3
# rho_Hg=13550 #kg/m3
# p_atm=101 #Pa
# Out:
# $$
# \begin{aligned}
# g &= 9.810 \; \;\textrm{(m/s2)}
#  &\rho_{water} &= 1000 \; \;\textrm{(kg/m3)}
#  &\rho_{Hg} &= 13550 \; \;\textrm{(kg/m3)}
# \\
#  p_{atm} &= 101 \; \;\textrm{(Pa)}
# \end{aligned}
# $$

# %% [markdown]
# ## Problems for Lecture 2: Basic	fluid	properties,	Ideal	gas	law,	Compressibility	of	liquids, and Surface tension

# %% [markdown]
# ### Basic fluid properties

# %%
# Automatically add 'remove-input' tag to all cells

#from notebook import notebookapp
#from IPython.display import display, Javascript

#def add_remove_input_tag():
#    display(Javascript('''
#        var cells = Jupyter.notebook.get_cells();
#        cells.forEach(function(cell) {
#            cell.metadata.tags = cell.metadata.tags || [];
#            if (cell.metadata.tags.indexOf('remove-input') === -1) {
#                cell.metadata.tags.push('remove-input');
#            }
#        });
#        Jupyter.notebook.save_notebook();
#    '''))

#add_remove_input_tag()

# %% [markdown]
# ---
# #### Question 1 (*)

# %% [markdown]
# If the specific volume of a gas is 0.70 m<sup>3 </sup>/kg, what is its specific weight?

# %% [markdown]
# ```{dropdown} Answer
# $14.01 \; N/m^3$
# ```

# %% [markdown]
# ```{dropdown} Hint
# Specific weight ($\gamma$) is the weight per unit volume $\gamma=\rho \cdot g$
#
# Specific volume ($v$) is the inverse of the density $v=\frac{1}{\rho}$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=03f3b3dc-8599-4fdf-99f6-b29401590dc4)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# v=0.7 #m3/kg
# rho= 1/v #kg/m3
# gamma= rho*g #N/m3
# Out:
# $$
# \begin{aligned}
# v &= 0.70 \; \;\textrm{(m3/kg)}
# \\
# \rho &= \frac{ 1 }{ v } \\&= \frac{ 1 }{ 0.70 } \\&= 1.43 \; \;\textrm{(kg/m3)}\\
# \\
# \gamma &= \rho \cdot g \\&= 1.43 \cdot 9.81 \\&= 14.01 \; \;\textrm{(N/m3)}\\
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 2 (*)[R]

# %% [markdown]
# ---
#
# A reservoir of glycerin has a mass of 1200 kg and a volume of 0.952 m<sup>3 </sup>. Find the glycerin’s weight, mass density, specific weight and specific gravity.

# %% [markdown]
# ```{dropdown} Answer
# $11.77 \; kN \;; 1261 \; kg/m^3 \; ; 12.36 \; N/m^3 \; ; 1.26$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The weight is given by the equation: $W=  m \cdot g$
#
# Mass density ($\rho$) is the mass divided by the volume $\rho=\frac{m}{Vol}$
#
# Specific weight ($\gamma$) is the weight per unit volume and can be calculated as $\gamma=\rho \cdot g$
#
# Specific gravity ($s$) is the ratio of the fluid’s density to the density of water at 4°C (i.e $1000 kg/m^3$):
#
# $s= \frac {\rho_{fluid}}{\rho_{water_{4c}}}$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=37fad609-170e-42d9-aeec-b294015a1971)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render 2 long
# m=1200 #kg
# Vol=0.952 #m3
# W= m*g #N
# rho_glycerin= m/Vol #kg/m3
# gamma_glycerin= rho_glycerin*g #N/m3
# s_glycerin= rho_glycerin/rho_water
# Out:
# $$
# \begin{aligned}
# m &= 1200 \; \;\textrm{(kg)}
# \\
# \mathrm{Vol} &= 0.95 \; \;\textrm{(m3)}
# \\
# W &= m \cdot g \\&= 1200 \cdot 9.81 \\&= 11772.00 \; \;\textrm{(N)}\\
# \\
# \rho_{glycerin} &= \frac{ m }{ \mathrm{Vol} } \\&= \frac{ 1200 }{ 0.95 } \\&= 1260.50 \; \;\textrm{(kg/m3)}\\
# \\
# \gamma_{glycerin} &= \rho_{glycerin} \cdot g \\&= 1260.50 \cdot 9.81 \\&= 12365.55 \; \;\textrm{(N/m3)}\\
# \\
# s_{glycerin} &= \frac{ \rho_{glycerin} }{ \rho_{water} } \\&= \frac{ 1260.50 }{ 1000 } \\&= 1.26  \\
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 3 (*)

# %% [markdown]
# The volume of a rock is found to be 0.00015 m<sup>3</sup>. If the rock’s specific gravity is 2.60, what is its weight?

# %% [markdown]
# ```{dropdown} Answer
# $3.83 \; N$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The weight of the rock can be calculated using the equation:
#
# $$W = \rho \cdot g \cdot Vol$$
#
# Since the specific gravity of the rock is given, the density can be determined using the equation:
#
# $$\rho = \rho_{{water}} \cdot s$$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=daa8122c-3eea-4cd3-9402-b294015a1a69)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 5
# Vol=0.00015 #m3
# s=2.6
# rho= rho_water*s #kg/m3
# W= rho*g*Vol #N
# Out:
# $$
# \begin{aligned}
# \mathrm{Vol} &= 0.00015 \; \;\textrm{(m3)}
# \\
# s &= 2.60000 \;
# \\
# \rho &= \rho_{water} \cdot s \\&= 1000 \cdot 2.60000 \\&= 2600.00000 \; \;\textrm{(kg/m3)}\\
# \\
# W &= \rho \cdot g \cdot \mathrm{Vol} \\&= 2600.00000 \cdot 9.81000 \cdot 0.00015 \\&= 3.82590 \; \;\textrm{(N)}\\
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 4 (*)

# %% [markdown]
# A certain gas weighs 16.0 N/m<sup>3 </sup> at a certain temperature and pressure. What are the values of its density, specific volume, and specific gravity relative to air weighing 12.0 N/m<sup>3 </sup>?

# %% [markdown]
# ```{dropdown} Answer
#
#  $1.63 \; kg/ mm^3 \; ; 0.61 \; mm^3/kg \; ; 1.33$
#  ```

# %% [markdown]
# ```{dropdown} Hint
# Specific weight ($\gamma$) is the weight per unit volume and can be calculated as $\gamma=\rho \cdot g$
#
# Specific volume is the inverse of the density: $v=\frac {1}{\rho_{gas}}$
#
# Specific gravity ($s$) is the ratio of the fluid’s density to the density of water at 4°C (i.e $1000 kg/m^3$):
#
# $s= \frac {\rho_{fluid}}{\rho_{water_{4c}}}$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=162ef364-baca-4097-ab05-b294015a1ad0)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# gamma_gas=16 #N/m3
# gamma_air=12 #N/m3
# rho_air= gamma_air/g  #kg/m3
# rho_gas= gamma_gas/g #kg/m3
# v= 1/rho_gas #m3/kg
# s_gas= rho_gas/rho_water
# s_air= rho_air/rho_water
# s=s_gas/s_air
# Out:
# $$
# \begin{aligned}
# \gamma_{gas} &= 16 \; \;\textrm{(N/m3)}
# \\
# \gamma_{air} &= 12 \; \;\textrm{(N/m3)}
# \\
# \rho_{air} &= \frac{ \gamma_{air} }{ g } \\&= \frac{ 12 }{ 9.8100 } \\&= 1.2232 \; \;\textrm{(kg/m3)}\\
# \\
# \rho_{gas} &= \frac{ \gamma_{gas} }{ g } \\&= \frac{ 16 }{ 9.8100 } \\&= 1.6310 \; \;\textrm{(kg/m3)}\\
# \\
# v &= \frac{ 1 }{ \rho_{gas} } \\&= \frac{ 1 }{ 1.6310 } \\&= 0.6131 \; \;\textrm{(m3/kg)}\\
# \\
# s_{gas} &= \frac{ \rho_{gas} }{ \rho_{water} } \\&= \frac{ 1.6310 }{ 1000 } \\&= 0.0016  \\
# \\
# s_{air} &= \frac{ \rho_{air} }{ \rho_{water} } \\&= \frac{ 1.2232 }{ 1000 } \\&= 0.0012  \\
# \\
# s &= 1.3333 \;
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 5 (*)

# %% [markdown]
# A 3-litre container is filled with a liquid that has a specific gravity of 0.9. Determine mass density, weight and specific volume of the fluid.

# %% [markdown]
# ```{dropdown} Answer
#
# $900 \; kg/m^3 \; ; 26.5 \; N \; ; 0.00111 \; m^3/kg$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The density of the liquid can be calculated using the specific gravity ($s$) equation, which is $s= \frac {\rho_{fluid}}{\rho_{water}}$.
#
# Weight is given by the equation: $W=\rho \cdot g \cdot Vol$
#
# Specific volume is the inverse of the density: $v=\frac {1}{\rho}$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=5b623807-8065-47ea-b729-b294015a19f3)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# Vol= 3/1000 #m3
# s=0.9
# rho= rho_water*s #kg/m3
# W= rho*g*Vol #N
# v= 1/rho #m3/kg
# Out:
# $$
# \begin{aligned}
# \mathrm{Vol} &= \frac{ 3 }{ 1000 } &= 0.0030 \; \;\textrm{(m3)}
# \\
# s &= 0.9000 \;
# \\
# \rho &= \rho_{water} \cdot s \\&= 1000 \cdot 0.9000 \\&= 900.0000 \; \;\textrm{(kg/m3)}\\
# \\
# W &= \rho \cdot g \cdot \mathrm{Vol} \\&= 900.0000 \cdot 9.8100 \cdot 0.0030 \\&= 26.4870 \; \;\textrm{(N)}\\
# \\
# v &= \frac{ 1 }{ \rho } \\&= \frac{ 1 }{ 900.0000 } \\&= 0.0011 \; \;\textrm{(m3/kg)}\\
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 6 (**)[R]

# %% [markdown]
# A fluid with a specific gravity of 1.2 moves through a pipe at rate of 2 000 kg every 6 hours. Calculate the mass density, specific weight and volumetric flowrate of the fluid.

# %% [markdown]
#  ```{dropdown} Answer
#
# $1200 \; kg/m^3 \; ; 11 772 \; N/m^3 \; ; 7.716 x 10^ {-5} \; m^3/s$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The density of the liquid can be calculated using the specific gravity ($s$) equation, which is $s= \frac {\rho_{fluid}}{\rho_{water}}$.
#
# Specific weight ($\gamma$) is the weight per unit volume and can be calculated as $\gamma=\rho \cdot g$
#
# The volumetric flow rate is the volume of fluid passing through a given section per unit of time. The equation used is: $Q= \frac {Vol}{t}$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=75e6f28e-1efa-4a20-afac-b294015a2140)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# s_fluid= 1.2
# m= 2000 #kg
# t= 6 #h
# rho_fluid= s_fluid*rho_water #kg/m3
# gamma_fluid= rho_fluid*g # N/m3
# Vol= m/rho_fluid #m3
# Q_h= Vol/t #m3/h
# Q_s= Vol/(t*60*60)*1000#L/s
# Out:
# $$
# \begin{aligned}
# s_{fluid} &= 1.200 \;
# \\
# m &= 2000 \; \;\textrm{(kg)}
# \\
# t &= 6 \; \;\textrm{(h)}
# \\
# \rho_{fluid} &= s_{fluid} \cdot \rho_{water} \\&= 1.200 \cdot 1000 \\&= 1200.000 \; \;\textrm{(kg/m3)}\\
# \\
# \gamma_{fluid} &= \rho_{fluid} \cdot g \\&= 1200.000 \cdot 9.810 \\&= 11772.000 \; \;\textrm{(N/m3)}\\
# \\
# \mathrm{Vol} &= \frac{ m }{ \rho_{fluid} } \\&= \frac{ 2000 }{ 1200.000 } \\&= 1.667 \; \;\textrm{(m3)}\\
# \\
# Q_{h} &= \frac{ \mathrm{Vol} }{ t } \\&= \frac{ 1.667 }{ 6 } \\&= 0.278 \; \;\textrm{(m3/h)}\\
# \\
# Q_{s} &= \frac{ \mathrm{Vol} }{ t \cdot 60 \cdot 60 } \cdot 1000 \\&= \frac{ 1.667 }{ 6 \cdot 60 \cdot 60 } \cdot 1000 \\&= 0.077 \; \;\textrm{(L/s)}\\
# \end{aligned}
# $$

# %% [markdown]
# ### Ideal	Gas	Law

# %% [markdown]
# ---
# #### Question 7 (*)

# %% [markdown]
# Calculate the specific weight, density and specific volume of air at 50 °C and absolute pressure of 3.4 bar. Given: R<sub>air</sub> = 287 m<sup>2</sup>/(s<sup>2</sup>.K).

# %% [markdown]
# ```{dropdown} Answer
# $
# 36 \; N/m^3 \; ; 3.67  \; kg/m^3 \; ; 0.27 \; m^3/kg
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# By using the ideal gas law, the density of air ($\rho$) can be calculated as:
#
# $$\rho = \frac{p}{R_{air} \cdot T}$$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=a53285f2-316d-42cc-aa83-b294015a224b)
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
# The values of $R_{air}$, $T$, and $p$ are given. We need to convert the temperature units to K and the pressure units to Pa, as required by the ideal gas law.
#
# By using the ideal gas law, the density of air ($\rho$) can be calculated as:
#
# $$\rho = \frac{p}{R_{air} \cdot T}$$
# where:
# - $p$ is the absolute pressure of the air
# - $R_{air}$ is the specific gas constant for air
# - $T$ is the absolute temperature of the air in Kelvin
#
# Once the density is known, the specific weight ($\gamma$) can be calculated using the equation $\gamma = \rho \cdot g$
#
# Finally, the specific volume is the inverse of the density $v =\frac{1}{\rho}$
# ```

# %%
# %%render long 2
# T_k= 50+273.15 #K
# p_Pa= 3.4*10**5 #Pa
# R_air= 287 #m2/(s2.K)
# rho= p_Pa/(R_air*T_k)#kg/m3
# gamma= rho*g#N/m3
# v= 1/rho #m3/kg
# Out:
# $$
# \begin{aligned}
# T_{k} &= 50 + 273.15 &= 323.15 \; \;\textrm{(K)}
# \\
# p_{Pa} &= 3.4 \cdot \left( 10 \right) ^{ 5 } &= 340000.00 \; \;\textrm{(Pa)}
# \\
# R_{air} &= 287 \; \;\textrm{(m2/(s2.K))}
# \\
# \rho &= \frac{ p_{Pa} }{ R_{air} \cdot T_{k} } \\&= \frac{ 340000.00 }{ 287 \cdot 323.15 } \\&= 3.67 \; \;\textrm{(kg/m3)}\\
# \\
# \gamma &= \rho \cdot g \\&= 3.67 \cdot 9.81 \\&= 35.96 \; \;\textrm{(N/m3)}\\
# \\
# v &= \frac{ 1 }{ \rho } \\&= \frac{ 1 }{ 3.67 } \\&= 0.27 \; \;\textrm{(m3/kg)}\\
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 8 (*)

# %% [markdown]
# Calculate the specific weight, density and specific volume of the air inside a car tyre at a temperature of 15°C and pumped to an absolute pressure of 3 bar. Given: R<sub>air</sub> = 287 m<sup>2</sup>/(s<sup>2</sup>.K).

# %% [markdown]
# ```{dropdown} Answer
#
# $
# 35.6 \; N/m^3 \; ; 3.63 \; kg/m^3 \; ; 0.28 \; m^3/kg
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# By using the ideal gas law, the density of air ($\rho$) can be calculated as:
#
# $$\rho = \frac{p}{R_{air} \cdot T}$$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=ab7a4e6d-443d-4c75-96a9-b294015a2517)
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
#
# The values of $R_{air}$, $T$, and $p$ are given. We need to convert the temperature units to K and the pressure units to Pa, as required by the ideal gas law.
#
# By using the ideal gas law, the density of air ($\rho$) can be calculated as:
#
# $$\rho = \frac{p}{R_{air} \cdot T}$$
#
# where:
# - $p$ is the absolute pressure of the air
# - $R_{air}$ is the specific gas constant for air
# - $T$ is the absolute temperature of the air in Kelvin
#
#
# Once the density is known, the specific weight ($\gamma$) can be calculated using the equation $\gamma = \rho \cdot g$
#
# Finally, the specific volume is the inverse of the density $v =\frac{1}{\rho}$
# ```

# %%
# %%render 2 Long
# T_k= 15+273.15 #K
# p_Pa= 3*10**5 #Pa
# R_air= 287 #m2/(s2.K)
# rho= p_Pa/(R_air*T_k) #kg/m3
# gamma= rho*g#N/m3
# v= 1/rho #m3/kg
# Out:
# $$
# \begin{aligned}
# T_{k} &= 15 + 273.15 &= 288.15 \; \;\textrm{(K)}
# \\
# p_{Pa} &= 3 \cdot \left( 10 \right) ^{ 5 } &= 300000 \; \;\textrm{(Pa)}
# \\
# R_{air} &= 287 \; \;\textrm{(m2/(s2.K))}
# \\
# \rho &= \frac{ p_{Pa} }{ R_{air} \cdot T_{k} } \\&= \frac{ 300000 }{ 287 \cdot 288.15 } \\&= 3.63 \; \;\textrm{(kg/m3)}\\
# \\
# \gamma &= \rho \cdot g \\&= 3.63 \cdot 9.81 \\&= 35.59 \; \;\textrm{(N/m3)}\\
# \\
# v &= \frac{ 1 }{ \rho } \\&= \frac{ 1 }{ 3.63 } \\&= 0.28 \; \;\textrm{(m3/kg)}\\
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 9 $(*)(**)$[R]

# %% [markdown]
# a)* Calculate the specific weight, density and specific volume of oxygen at 20 °C and 50 kN/m<sup>2</sup> absolute.
# Given: R<sub>oxygen</sub> = 260 m<sup>2</sup>/(s<sup>2</sup>.K).
#
# b)** If the oxygen is enclosed in a rigid container of constant volume, what will the pressure be if the temperature is reduced to  0°C?

# %% [markdown]
# ```{dropdown} Answer
#
# $
# a) \; 6.44 \; N/m^3 \; ; \; 0.656 \; kg/m^3 \; ; \; 1.524 \; m^3/kg
# $
#
# $
# b) \; 46.6 \; kPa
# $
# ```

# %% [markdown]
# **Question 9 (a)**

# %% [markdown]
# ```{dropdown} Hint
# By using the ideal gas law, the density of air ($\rho$) can be calculated as:
#
# $$\rho = \frac{p}{R_{oxygen} \cdot T}$$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=8633f197-c5a3-40cf-9653-b294015a2635)
#
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# The values of $R_{oxygen}$, $T$, and $p$ are given. We need to convert the temperature units to K and the pressure units to Pa, as required by the ideal gas law.
#
# By using the ideal gas law, the density of air ($\rho$) can be calculated as:
#
# $$\rho = \frac{p}{R_{oxygen} \cdot T}$$
#
# where:
# - $p$ is the absolute pressure of the air
# - $R_{oxygen}$ is the specific gas constant for air
# - $T$ is the absolute temperature of the air in Kelvin
#
# Once the density is known, the specific weight ($\gamma$) can be calculated using the equation $\gamma = \rho \cdot g$
#
# Finally, the specific volume is the inverse of the density $v =\frac{1}{\rho}$
# ```

# %%
# %%render long
# T= 20+273.15 #K
# p= 50*1000 #Pa
# R_oxygen=260 #m2/(s2.K)
# gamma= (g*p)/(R_oxygen*T) #N/m3
# rho= gamma/g #kg/m3
# v= 1/rho #m3/kg
# Out:
# $$
# \begin{aligned}
# T &= 20 + 273.15 &= 293.150 \; \;\textrm{(K)}
# \\
# p &= 50 \cdot 1000 &= 50000 \; \;\textrm{(Pa)}
# \\
# R_{oxygen} &= 260 \; \;\textrm{(m2/(s2.K))}
# \\
# \gamma &= \frac{ g \cdot p }{ R_{oxygen} \cdot T } \\&= \frac{ 9.810 \cdot 50000 }{ 260 \cdot 293.150 } \\&= 6.435 \; \;\textrm{(N/m3)}\\
# \\
# \rho &= \frac{ \gamma }{ g } \\&= \frac{ 6.435 }{ 9.810 } \\&= 0.656 \; \;\textrm{(kg/m3)}\\
# \\
# v &= \frac{ 1 }{ \rho } \\&= \frac{ 1 }{ 0.656 } \\&= 1.524 \; \;\textrm{(m3/kg)}\\
# \end{aligned}
# $$

# %% [markdown]
# **Question 9 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The ideal gas law is given by the following equation:
#
# $$\rho = \frac{p}{R_{oxygen} \cdot T}$$
#
# The $R_{oxygen}$ and the volume ($Vol$) are constant in both scenarios.
#
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# The ideal gas law is given by the following equation:
#
# $$\rho = \frac{p}{R_{oxygen} \cdot T}$$
#
# Considering that the $R_{oxygen}$ is constant we have:
#
# $$R= \frac {p_1 \cdot Vol_1}{T_1} = \frac {p_2 \cdot Vol_2}{T_2}$$
#
# The $Vol$ from both scenarios are the same, thus
#
# $$\frac{p_2}{T_2}=\frac{p_1}{T_1}$$
# ```

# %%
# %%render long 2
# p_1=50*1000 #Pa
# T_1=20+273.15 #K
# T_2=0+273.15 #K
# p_2= (p_1*T_2)/T_1 #Pa
# p_2_= p_2/1000 #kPa
# Out:
# $$
# \begin{aligned}
# p_{1} &= 50000 \; \;\textrm{(Pa)}
# \\
# T_{1} &= 293.15 \; \;\textrm{(K)}
# \\
# T_{2} &= 273.15 \; \;\textrm{(K)}
# \\
# p_{2} &= \frac{ p_{1} \cdot T_{2} }{ T_{1} } \\&= \frac{ 50000 \cdot 273.15 }{ 293.15 } \\&= 46588.78 \; \;\textrm{(Pa)}\\
# \\
# p_{2_{}} &= \frac{ p_{2} }{ 1000 } \\&= \frac{ 46588.78 }{ 1000 } \\&= 46.59 \; \;\textrm{(kPa)}\\
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 10 (***)

# %% [markdown]
# a) If water vapour in the atmosphere has a partial pressure of 3500 Pa and the temperature is 30 °C, what is its specific weight?
#
# b) If the atmospheric pressure is 102 kPa, what is the partial pressure of the (dry) air, and its specific weight?
#
# c) What is the specific weight of the atmosphere (air plus water vapour present)?
#
# Given: R<sub>air</sub> = 287 m<sup>2</sup>/(s<sup>2</sup>.K); R <sub>water vapour</sub> = 462 m<sup>2</sup>(s<sup>2</sup>.K).

# %% [markdown]
#  ```{dropdown} Answer
#
# $
# a) \; 0.25 \; N/m^3
# $
#
# $
# b) \;  11.11 \; N/m^3
# $
#
# $
# c) \;  11.36 \; N/m^3
# $
#  ```

# %% [markdown]
# **Question 10 (a)**

# %% [markdown]
# ```{dropdown} Hint
# By using the ideal gas law, the density of air ($\rho$) can be calculated as:
#
# $$\rho = \frac{p}{R_{wvapour} \cdot T}$$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=d4c95596-571d-4d56-a618-b294015a27a8)
#  ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# The values of $R_{wvapour}$, $T$, and $p$ are given. We need to convert the temperature units to K and the pressure units to Pa, as required by the ideal gas law.
#
# By using the ideal gas law, the density of air ($\rho$) can be calculated as:
#
# $$\rho = \frac{p}{R_{wvapour} \cdot T}$$
#
# where:
# - $p$ is the absolute pressure of the air
# - $R_{wvapour}$ is the specific gas constant for air
# - $T$ is the absolute temperature of the air in Kelvin
#
# Once the density is known, the specific weight ($\gamma$) can be calculated using the equation $\gamma = \rho \cdot g$
#
# Replacing the density equation into the specific weight we have:  $\gamma = \frac{g \cdot p}{R_{oxygen} \cdot T}$
# ```

# %%
# %%render 2
# p_Pa= 3500 #Pa
# T_k= 30+273.15 #K
# R_wvapour= 462 #m2/(s2.K)
# p_barometer=102*1000 #Pa
# R_air=287 #m2/(s2.K)
# gamma_wvapour= (g*p_Pa)/(R_wvapour*T_k) #N/m3
# Out:
# $$
# \begin{aligned}
# p_{Pa} &= 3500 \; \;\textrm{(Pa)}
# \\
# T_{k} &= 30 + 273.15 &= 303.15 \; \;\textrm{(K)}
# \\
# R_{wvapour} &= 462 \; \;\textrm{(m2/(s2.K))}
# \\
# p_{barometer} &= 102000 \; \;\textrm{(Pa)}
# \\
# R_{air} &= 287 \; \;\textrm{(m2/(s2.K))}
# \\
# \gamma_{wvapour} &= \frac{ g \cdot p_{Pa} }{ R_{wvapour} \cdot T_{k} }  = \frac{ 9.81 \cdot 3500 }{ 462 \cdot 303.15 } &= 0.25 \; \;\textrm{(N/m3)}
# \end{aligned}
# $$

# %% [markdown]
# **Question 10 (b)**

# %% [markdown]
# ```{dropdown} Hint
#
#
# The partial pressure can be calculated as $p_{partial}=p_{total}-p_{v}$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render 2 long
# p_air_Pa= p_barometer-p_Pa #kPa
# gamma_air= (g*p_air_Pa)/(R_air*T_k) #N/m3
# Out:
# $$
# \begin{aligned}
# p_{air_{Pa}} &= p_{barometer} - p_{Pa} \\&= 102000 - 3500 \\&= 98500 \; \;\textrm{(kPa)}\\
# \\
# \gamma_{air} &= \frac{ g \cdot p_{air_{Pa}} }{ R_{air} \cdot T_{k} } \\&= \frac{ 9.81 \cdot 98500 }{ 287 \cdot 303.15 } \\&= 11.11 \; \;\textrm{(N/m3)}\\
# \end{aligned}
# $$

# %% [markdown]
# **Question 10 (c)**

# %% [markdown]
# ```{dropdown} Hint
#
#
# The specific weight of the atmosphere including the water vapour and the air is
#
# $$\gamma_{atm}=\gamma_{air}+\gamma_{water}$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# gamma_atmos= gamma_air+gamma_wvapour #N/m3
# Out:
# $$
# \begin{aligned}
# \gamma_{atmos} &= \gamma_{air} + \gamma_{wvapour} \\&= 11.11 + 0.25 \\&= 11.35 \; \;\textrm{(N/m3)}\\
# \end{aligned}
# $$

# %% [markdown]
# ### Compressibility	of	Liquids

# %% [markdown]
# ---
# #### Question 11 (*)

# %% [markdown]
# What pressure in MPa must be applied to water to reduce its volume by 3% under standard sea level atmospheric conditions?

# %% [markdown]
# ```{dropdown} Answer
#
# $64.2 \; MPa$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The compressibility of liquids is described by the following equation:
#
# $$\Delta p =-E_v \frac{\Delta v}{v}$$
#
# The bulk modulus $E_v$ can be found in a table of the physical properties of common liquids at standard sea-level atmospheric conditions.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=d3a614bf-9c88-408a-9614-b294015a29a8)
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# The compressibility of liquids is described by the following equation:
#
# $$\Delta p =-E_v \frac{\Delta v}{v}$$
#
# Where:
# - $\Delta p$ is the change in pressure
# - $E_v$ is the bulk modulus of elasticity
# - $\Delta v$ is the change in the specific volume
# - $v$ is the original specific volume
#
# Specific volume ($v$) can be calculated with the following equation:
#
# $$
# v= \frac{1}{\rho}= Vol/m
# $$
#
# From the ICAO table, the physical properties of water at standard sea-level atmospheric pressure $E_v$ at T=288.15 K (T=15°C) is 2.14x10<sup>9</sup> Pa.
# ```

# %%
# %%render long 2
# Delta_Vol= 3/100
# T= 15+273.15 #K
# E_v=2.14*10**9 #Pa
# Delta_p= -E_v*-Delta_Vol #Pa
# Delta_p_= Delta_p/1000000 #MPa
# Out:
# $$
# \begin{aligned}
# \Delta_{Vol} &= \frac{ 3 }{ 100 } &= 0.03
# \\
# T &= 15 + 273.15 &= 288.15 \; \;\textrm{(K)}
# \\
# E_{v} &= 2140000000.00 \; \;\textrm{(Pa)}
# \\
# \Delta_{p} &= \left( - E_{v} \right) \cdot \left( - \Delta_{Vol} \right) \\&= \left( - 2140000000.00 \right) \cdot \left( - 0.03 \right) \\&= 64200000.00 \; \;\textrm{(Pa)}\\
# \\
# \Delta_{p_{}} &= \frac{ \Delta_{p} }{ 1000000 } \\&= \frac{ 64200000.00 }{ 1000000 } \\&= 64.20 \; \;\textrm{(MPa)}\\
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 12 (*)[R]

# %% [markdown]
# By what fraction will the volume of a given quantity of mercury at 20°C be reduced if the pressure on it is increased by 100 MPa?

# %% [markdown]
# ```{dropdown} Answer
#
# $0.38 \; \% $
# ```

# %% [markdown]
# ```{dropdown} Hint
# The compressibility of liquids is described by the following equation:
#
# $$\Delta p =-E_v \frac{\Delta v}{v}$$
#
# The bulk modulus $E_v$ can be found in a table of the physical properties of common liquids at standard sea-level atmospheric conditions.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=94eb05ee-3d14-4948-98ff-b294015a2b27)
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# The compressibility of liquids is described by the following equation:
#
# $$ \Delta p =-E_v \frac{\Delta v}{v} $$
#
# Where:
#
# - $\Delta p$ is the change in pressure
# - $E_v$ is the bulk modulus of elasticity
# - $\Delta v$ is the change in the specific volume
# - $v$ is the original specific volume
#
# Solving for the reduction of volume $\frac{\Delta Vol}{Vol}$, we have
#
# $$\frac{\Delta Vol}{Vol}=\frac{-\Delta p}{E_v}$$
#
# Additionally, using a table of the physical properties of common liquids at the standard sea-level atmospheric conditions the Ev is: 26.9x10<sup>9</sup> N/m<sup>2</sup>
# ```

# %%
# %%render long 2
# Delta_p=100*10**6 #MPa
# E_v=26.2*10**9 #N/m2
# Vol_percentage= (-Delta_p/E_v)*100 #%
# Out:
# $$
# \begin{aligned}
# \Delta_{p} &= 100000000 \; \;\textrm{(MPa)}
# \\
# E_{v} &= 26200000000.00 \; \;\textrm{(N/m2)}
# \\
# \mathrm{Vol}_{percentage} &= \left( \frac{ \left( - \Delta_{p} \right) }{ E_{v} } \right) \cdot 100 \\&= \left( \frac{ \left( - 100000000 \right) }{ 26200000000.00 } \right) \cdot 100 \\&= -0.38 \; \;\textrm{(%)}\\
# \end{aligned}
# $$

# %% [markdown]
# ---
# #### Question 13 (***)

# %% [markdown]
# A rigid cylinder with inside diameter of 15 mm contains a column of water 500 mm long. What will the column length be if a force of 2 kN is applied to its top by a frictionless plunger? Assume a bulk modulus of 2.21 GPa.

# %% [markdown]
# ```{dropdown} Answer
#
# $497 \; mm$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The compressibility of liquids is described by the following equation:
#
# $$\Delta p =-E_v \frac{\Delta v}{v}$$
#
# The change in pressure can be calculated using the force and area as:
#
# $$ \Delta p = \frac {\Delta F}{A}$$
#
# The cylinder's cross-sectional area is fixed, but the column length is changing, modifying the fluid's volume
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=21e9c540-fff5-445e-8313-b294015a2d1e)
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# The compressibility of liquids is described by the following equation:
#
# $$\Delta p =-E_v \frac{\Delta v}{v}\\
# $$
# where:
#
# - $\Delta p$ is the change in pressure
# - $E_v$ is the bulk modulus of elasticity
# - $\Delta v$ is the change in the specific volume
# - $v$ is the original specific volume
#
# The change in pressure can be calculated using the force and area as:
#
# $$\Delta p = \frac {\Delta F}{A}$$
#
# Changing specific volume with the following equation, we have
#
# $$\frac {\Delta v }{v}= \frac {\frac{\Delta Vol}{m}}{\frac{Vol}{m}}$$
#
# Knowing that the change in volume is due to the change in length since the area remains constant, we have the following:
#
# $$
# \frac {\Delta v }{v}= \frac{L_2-L_1}{L_1}
# $$
#
# Substituting into the compressibility equation, we have:
#
# $$\Delta p =-E_v \frac{L_2-L_1}{L_1}$$
#
# Solving for $L_2$:
#
# $$L_2 = -L_1 \cdot \frac{\Delta p}{E_v}+ L_1$$
# ```

# %%
# %%render long 4
# dF=2000 #N
# d=0.015 #m
# L_1=0.5 #m
# E_v= 2.21*10**9 #Pa
# A= pi*(d/2)**2 #m2
# dp= dF/A #Pa
# L_2= -L_1*dp/E_v+L_1 #m
# L_2_=L_2*1000 #mm
# Out:
# $$
# \begin{aligned}
# \mathrm{dF} &= 2000 \; \;\textrm{(N)}
# \\
# d &= 0.0150 \; \;\textrm{(m)}
# \\
# L_{1} &= 0.5000 \; \;\textrm{(m)}
# \\
# E_{v} &= 2.21 \cdot \left( 10 \right) ^{ 9 } &= 2210000000.0000 \; \;\textrm{(Pa)}
# \\
# A &= \pi \cdot \left( \frac{ d }{ 2 } \right) ^{ 2 } \\&= 3.1416 \cdot \left( \frac{ 0.0150 }{ 2 } \right) ^{ 2 } \\&= 0.0002 \; \;\textrm{(m2)}\\
# \\
# \mathrm{dp} &= \frac{ \mathrm{dF} }{ A } \\&= \frac{ 2000 }{ 0.0002 } \\&= 11317684.8421 \; \;\textrm{(Pa)}\\
# \\
# L_{2} &= \left( - L_{1} \right) \cdot \frac{ \mathrm{dp} }{ E_{v} } + L_{1} \\&= \left( - 0.5000 \right) \cdot \frac{ 11317684.8421 }{ 2210000000.0000 } + 0.5000 \\&= 0.4974 \; \;\textrm{(m)}\\
# \\
# L_{2_{}} &= 497.4394 \; \;\textrm{(mm)}
# \end{aligned}
# $$

# %% [markdown]
# ## Problems for Lecture 3: Vapour pressure and surface tension

# %% [markdown]
# ### Vapour Pressure

# %% [markdown]
# ---
# #### Question 1 (*)[R]

# %% [markdown]
#  At approximately what temperature will water boil at top of Mount Everest (elevation 8 850 m above sea level)?

# %% [markdown]
# ```{dropdown} Answer
# $70 \; °C$
# ```

# %% [markdown]
# ```{dropdown} Hint
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=21e9c540-fff5-445e-8313-b294015a2d1e)
#
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# A fluid will boil when its saturation vapour pressure is greater than or equal to the pressure.
#
# From the ICAO standard atmosphere table, the absolute pressure at 8850 m above sea level is 32000 Pa.
#
# From the Physical properties of water at standard sea-level atmospheric pressure table, water has a saturation vapour pressure of 32000 Pa at 70°C.
#
# ```

# %% [markdown]
# ---
# #### Question 2 (*)

# %% [markdown]
# At approximately what elevation will water boil at 90 °C?

# %% [markdown]
# ```{dropdown} Answer
#
# $3000 \; m$
# ```

# %% [markdown]
# ```{dropdown} Hint
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=c96014f4-2285-4921-9896-b294015a47ec)
#
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# From the Physical properties of water at standard sea-level atmospheric pressure table, water has a saturation vapour pressure of 70.1 kPa at 90°C.
#
# From the ICAO standard atmosphere table, the absolute pressure at 70 kPa is 3000 m.
# ```

# %% [markdown]
# ---
# #### Question 3 (**)[R]

# %% [markdown]
# Water at 75°C is placed in a beaker in an airtight container. Air is gradually pumped out of the container. What reduction below standard sea level atmospheric pressure must be achieved before the water boils?

# %% [markdown]
# ```{dropdown} Answer
#
# $62.325 \; kPa$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The pressure reduction is:
#
# $dp=p_{atm}-p_{vp}$
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=68749cee-fccf-4e9f-baa5-b294015a5d02)
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown}  Show code cell outputs
# The pressure reduction can be calculated as the difference between the standard sea level atmospheric pressure and the saturation vapour pressure:
#
# $dp=p_{atm}-p_{vp}$
#
# From the ICAO standard atmosphere table, the standard sea level atmospheric pressure is 101.325 kPa. And from the Physical properties of water at standard sea-level atmospheric pressure table, the saturation vapour pressure at 75°C is 39 kPa.
# ```

# %%
# %%render long
# p_vp=39 #kPa
# p_atm_= 101 #kPa
# dp= p_atm_-p_vp #kPa
# Out:
# $$
# \begin{aligned}
# p_{vp} &= 39 \; \;\textrm{(kPa)}
# \\
# p_{atm_{}} &= 101 \; \;\textrm{(kPa)}
# \\
# \mathrm{dp} &= p_{atm_{}} - p_{vp} \\&= 101 - 39 \\&= 62 \; \;\textrm{(kPa)}\\
# \end{aligned}
# $$

# %% [markdown]
# ### Surface Tension

# %% [markdown]
# ---
# #### Question 4 (*)

# %% [markdown]
# Calculate the capillary rise of pure water at 10 °C expected in an 0.8 mm diameter tube.  Assume that the contact angle of pure water is 0°.

# %% [markdown]
# ```{dropdown} Answer
# $37.8 \; mm$
# ```

# %% [markdown]
# ```{dropdown} Hint
# - Create a body diagram of the rising fluid.
# - Apply Equilibrium (Newton I).
# - The downward force is the weight of the fluid.
# - The upward force is equal to the vertical component of the surface tension multiplied by the length of the interface between the water and glass.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=0440b419-982c-4e52-b60d-b294015a769e)
#
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/L3Q4-6s.png")
img= img.resize((490,400))
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 from PIL import Image
# ----> 2 img = Image.open(r"figures/L3Q4-6s.png")
#       3 img= img.resize((490,400))
#       4 img
#
# File ~/.local/lib/python3.12/site-packages/PIL/Image.py:3635, in open(fp, mode, formats)
#    3633 if is_path(fp):
#    3634     filename = os.fspath(fp)
# -> 3635     fp = builtins.open(filename, "rb")
#    3636     exclusive_fp = True
#    3637 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/L3Q4-6s.png'

# %% [markdown]
# ```{dropdown} Show code cell outputs
# $\sum F_y=0$ Equilibrium (Newton I)
#
# $F_{\sigma y}-W=0$
#
# $\sigma cos \theta \pi d = \rho g \frac{\pi d^2}{4} h$
# ```

# %%
# %%render long 2
# d=0.8/1000 #m
# T=10 #°C
#
# sigma=0.0742 #N/m
# gamma= 9804 #kN/m3
#
# h_m= (2*sigma)/(gamma*(d/2)) #m
# h_mm= h_m*1000 #mm

# %% [markdown]
# ---
# #### Question 5 (*)[R]

# %% [markdown]
# A glass tube with diameter 1.5 mm is dipped vertically in water. Calculate from basic principles how high the water will rise in the tube due to capillary action. Take the coefficient of surface tension to be 0.0730 N/m and the angle of contact as 10°.

# %% [markdown]
# ```{dropdown} Answer
#
# $19.5 \; mm$
# ```

# %% [markdown]
# ```{dropdown} Hint
# - Create a body diagram of the rising fluid.
# - Apply Equilibrium (Newton I).
# - The downward force is the weight of the fluid.
# - The upward force is equal to the vertical component of the surface tension multiplied by the length of the interface between the water and glass.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=f4550463-0b65-4c53-9479-b294015aaa74)
#
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures\L3Q4-6s.png")
img= img.resize((490,400))
img

# %% [markdown]
# ```{dropdown} Show code cell outputs
# $\sum F_y=0$ Equilibrium (Newton I)
#
# $F_{\sigma y}-W=0$
#
# $\sigma cos \theta \pi d = \rho g \frac{\pi d^2}{4} h$
#
# ```

# %%
# %%render long 4
# d_tube=1.5/1000 #m
# sigma=0.0730 #N/m
# theta=10 #°
#
# theta_rad = radians(theta) #rad
#
# F_sigma= sigma*pi*d_tube*cos(theta_rad) #N
# h= F_sigma*4/(d_tube**2*rho_water*g*pi) #m
# h_mm = h_=h*1000 #mm

# %% [markdown]
# ---
# #### Question 6 (*)

# %% [markdown]
# A glass tube with diameter 1 mm is dipped vertically in water. Calculate from basic principles how high the water will rise in the tube due to capillary action. Take the coefficient of surface tension to be 0.0730 N/m and the angle of contact as 20°.

# %% [markdown]
# ```{dropdown} Answer
#
# $28 \; mm$
# ```

# %% [markdown]
# ```{dropdown} Hint
# - Create a body diagram of the rising fluid.
# - Apply Equilibrium (Newton I).
# - The downward force is the weight of the fluid.
# - The upward force is equal to the vertical component of the surface tension multiplied by the length of the interface between the water and glass.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=36407e19-ab4f-4c15-901e-b294015aad41)
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures\L3Q4-6s.png")
img= img.resize((490,400))
img

# %% [markdown]
# ```{dropdown} Show code cell outputs
# $\sum F_y=0$ Equilibrium (Newton I)
#
# $F_{\sigma y}-W=0$
#
# $\sigma cos \theta \pi d = \rho g \frac{\pi d^2}{4} h$
#
# ```

# %%
# %%render long 3
# d=1/1000 #m
# sigma=0.073 #N/m
# theta=20 #°
# h= (4*sigma*cos(radians(theta)))/(d*rho_water*g) #m
# h_mm= h*1000 #mm

# %% [markdown]
# ## Problems for Lecture 4: Viscosity

# %% [markdown]
# ### Viscosity

# %% [markdown]
# ---
# #### Question 1 (*)

# %% [markdown]
# A square block has a contact area of 0.02 m<sup>2 </sup>  with a table that is lubricated with a 0.1 mm thick layer of oil with viscosity 7 mPa.s. What force is required to move the block at a constant velocity of 1 m/s?

# %% [markdown]
# ```{dropdown} Answer
#
# $1.4 \; N$
# ```

# %% [markdown]
# ```{dropdown} Hint
# Since the block moves at constant velocity, the forces actig on it are in equilibrium.
#
# The shear stress or the block can be calculated from the viscosity equation.
#
# Assume a linear velocity profile.
#
# THe viscosity force on the block is the shear stress × area.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=83f6558d-6e54-4997-82aa-b29d01753e15)
#
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/4_viscosity_1.png")
base_width = 350 # Change this to your desired width
w_percent = base_width / float(img.size[0])
h_size = int(float(img.size[1]) * w_percent)
resized_img = img.resize((base_width, h_size))
resized_img

# %% [markdown]
# ```{dropdown} Show code cell outputs
# $$
# \sum F_{x}=0\quad;\quad\text{Newton Ⅰ (equilibrium)}
# $$
#
# $$
# F-\tau A=0
# $$
#
# $$
# \tau = \mu \frac{du}{dy}
# $$
#
# Assume a linear velocity profile in the oil
#
# ```

# %%
# %%render long 4
# A=0.02 #m2
# y=0.1 #mm
# mu_oil=7*10**-3 #Pa.s
# Delta_u = 1 #m/s
# Delta_y= y/1000 #m
# tau= mu_oil*(Delta_u/Delta_y) #Pa
# F= tau*A #N

# %% [markdown]
# ---
# #### Question 2 (**)[R]

# %% [markdown]
# A space 16 mm wide between two large plane surfaces is filled with oil with a viscosity μ = 0.18 N.s/m<sup>2</sup>. What force F will be required to drag a very thin plate of 0.4 m<sup>2</sup> area between the surfaces at a speed of 0.25 m/s if the plate is positioned 5 mm from the bottom surface?

# %% [markdown]
# ```{dropdown} Answer
#
# $5.24 \; N$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The sum of forces on the plate are in equilibrium since it is moving at a constant velocity.
#
# The shear stress on the plate can be calculated from the viscosity equation.
#
# Assume a linear velocity profile
#
# The viscosity force on the plate is the shear stress × area.
#
# The shear stress will be different on the top and bottom of the plate.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=bde38137-9963-4098-bef5-b29d01753e14)
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/4_viscosity_2.png")
base_width = 350 # Change this to your desired width
w_percent = base_width / float(img.size[0])
h_size = int(float(img.size[1]) * w_percent)
resized_img = img.resize((base_width, h_size))
resized_img

# %% [markdown]
# ```{dropdown} Show code cell outputs
# $$
# \sum F_{x}=0\quad;\quad\text{Newton Ⅰ (equilibrium)}
# $$
#
# $$
# F-F_{\tau_{1}}-F_{\tau_{2}}=0
# $$
#
# $$
# F=F_{\tau_{1}}+F_{\tau_{2}}
# $$
# ```

# %%
# %%render long 3
# mu=0.18 #N.s/m2
# u=0.25 #m/s
# Delta_y_2=5/1000 #m
# y=16/1000 #m
# A=0.4 #m2
#
# Delta_y_1= y-Delta_y_2 #m
# tau_1= mu*(u/Delta_y_1) #N/m2
# tau_2= mu*(u/Delta_y_2) #N/m2
# F_tau_1= tau_1*A #N
# F_tau_2= tau_2*A #N
# F= F_tau_1+F_tau_2 #N

# %% [markdown]
# ---
# #### Question 3 (**)

# %% [markdown]
# A space 10 mm wide between two large plane surfaces is filled with oil with viscosity μ = 0.18 N.s/m<sup>2</sup>. A very thin plate with a 0.5 m<sup>2</sup> area is located halfway between the two surfaces. If a constant force of 10 N is applied the plate, at what speed will it be dragged out from between the surfaces?

# %% [markdown]
# ```{dropdown} Answer
#
# $0.278 \; m/s$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The forces on the plate are in equilidrium since it is moving at a constant velocity.
#
# The shear stress on the plate can be calculated from the viscosity equation.
#
# The shear stress will act on both sides of the plate.
#
# Assume a linear velocity profile.
#
# The viscosity force on the plate is the shear stress × area.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=dfaf311f-e3d5-4bdc-abb4-b29d01753e14)
#
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/4_viscosity_3.png")
base_width = 350 # Change this to your desired width
w_percent = base_width / float(img.size[0])
h_size = int(float(img.size[1]) * w_percent)
resized_img = img.resize((base_width, h_size))
resized_img

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
# $$
# \sum F_{x}=0\quad;\quad\text{Newton Ⅰ (equilibrium)}
# $$
#
# $$
# F-2F_{\tau}=0
# $$
#
# Assume linear velocity distribution
#
# $$
# F = 2A \mu \frac{\mathrm{d} u}{\mathrm{d} y}
# $$
#
# $$
# \Delta u = F \frac{\Delta y}{2 \mu A}
# $$
# ```

# %%
# %%render long 3
# A=0.5 #m2
# y=10/1000 #m
# mu =0.18 #N.s/m2
# F= 10 #N
#
# Delta_y= y/2 #m
# u= (F * Delta_y) / (2 * A * mu) #m/s

# %% [markdown]
# ---
# #### Question 4 (**)[R]

# %% [markdown]
#  A square block weighing 1.1 kN and with side lengths of 250 mm slides down a 20 °  incline on a film of oil 6.0 micrometre thick. Assuming a linear velocity profile in the oil, what is the terminal velocity of the block? The viscosity of the oil is 7 mPa.s.

# %% [markdown]
# ```{dropdown} Answer
#
# $5.16 \; m/s$
# ```

# %% [markdown]
# ```{dropdown} Hint
# At terminal velocity, the block is moving at a constant speed, meaning the net force acting on it is zero.
#
# Select axis parallel to incline.
#
# Calculate weight component in $x$ direction.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=63039f1e-5093-4a0c-8f94-b29d01753e0f)
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/4_viscosity_4.png")
base_width = 350 # Change this to your desired width
w_percent = base_width / float(img.size[0])
h_size = int(float(img.size[1]) * w_percent)
resized_img = img.resize((base_width, h_size))
resized_img

# %% [markdown]
# ```{dropdown} Show code cell outputs
# $$
# \sum F_{x}=0\quad;\quad\text{Newton Ⅰ (equilibrium)}
# $$
#
# $$
# F-W\sin\theta=0\\
# $$
#
# $$
# \tau A = W\sin\theta
# $$
#
# Assume linear velocity distribution
#
# $$
# \mu\frac{\mathrm{d} u}{\mathrm{d} y}=W\sin\theta
# $$
#
# $$
# \Delta u = \frac{\Delta y W\sin\theta}{\mu}
# $$
#
# ```

# %%
# %%render long 6
# W=1.1*10**3 #N
# theta=20 #°
# Delta_y=6*10**-6 #m
# mu=7*10**-3 #Pa.s
# b=250/1000 #m
#
# A= b**2 #m2
# Delta_u= (W*sin(radians(theta))*Delta_y)/(A*mu) #m/s

# %% [markdown]
# ---
# #### Question 5 (***)

# %% [markdown]
#  A hydraulic lift consist of a 280 mm diameter ram which slides in a 280.18 mm  cylinder, the annular space being filled with oil having a kinematic viscosity of 0.00042 m<sup>2</sup>/s and a specific gravity of 0.86. If the rate of travel of the ram is 0.22 m/s, find the frictional resistance when 2 m of the ram is engaged in the cylinder.

# %% [markdown]
# ```{dropdown} Answer
#
# $1553 \; N$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The cylinder is static and the rod moving through it.
#
# Calculte the viscosity force on the ram.
#
# Kinematic viscosity is given, not dynamic viscosity.
#
# The space between the ram and cylinder is half the difference in the diameters.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=ab0ffd62-cec2-4235-ba6f-b29d017551c2)
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/4_viscosity_5.png")
base_width = 350 # Change this to your desired width
w_percent = base_width / float(img.size[0])
h_size = int(float(img.size[1]) * w_percent)
resized_img = img.resize((base_width, h_size))
resized_img

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
# $$
# \tau = \mu \frac{du}{dy}
# $$
#
# Assume linear velocity profile.
#
# $$
# \tau = \mu \frac{\Delta u}{\Delta y}
# $$
#
# ```

# %%
# %%render long 5
# d_ram= 280/1000 #m
# d_cyl=280.18/1000 #m
# nu= 0.00042 #m2/s
# s=0.86
# Delta_u=0.22 #m/s
# L=2 #m
#
# rho= s*rho_water #kg/m3
# mu= nu*rho #Pa.s
# Delta_y= (d_cyl-d_ram)/2 #m
#
# tau= mu*Delta_u/(Delta_y) #Pa
# A= L*pi*d_ram #m2
# F= tau*A #N

# %% [markdown]
# ---
# #### Question 6 (***)

# %% [markdown]
# A piston with diameter of 127 mm, height 152 mm and weight 93.4 N slides free in a lubricated vertical pipe. The clearance between the piston and the pipe is 0.0254 mm. If the piston decelerates at 0.64 m/s<sup>2</sup> when its speed is 6.4 m/s, what is the viscosity of the oil?

# %% [markdown]
# ```{dropdown} Answer
#
# $0.0065 \; N.s/m^2$
# ```

# %% [markdown]
# ```{dropdown} Hint
# Acceleration is occuring. Thus apply Newton's Second Law.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=2e6f2903-5bd6-4291-b968-b29d01755ea5)
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/4_viscosity_6.png")
base_width = 350 # Change this to your desired width
w_percent = base_width / float(img.size[0])
h_size = int(float(img.size[1]) * w_percent)
resized_img = img.resize((base_width, h_size))
resized_img

# %%
from PIL import Image
img = Image.open(r"figures/4_viscosity_6_diagram.png")
base_width = 350 # Change this to your desired width
w_percent = base_width / float(img.size[0])
h_size = int(float(img.size[1]) * w_percent)
resized_img = img.resize((base_width, h_size))
resized_img

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
# $$
# \sum F = ma\quad;\quad\text{Newton Ⅱ}
# $$
# $$
# F_\tau - W=ma
# $$
#
# Assume linear velocity distribution
#
# $$
# F_\tau=\mu \frac{\Delta u}{\Delta y}A
# $$
#
# $$
# \mu \frac{\Delta u}{\Delta y}A-W=ma
# $$
# ```

# %%
# %%render long 7
# d=127/1000 #m
# h=152/1000 #m
# W=93.4 #N
# Delta_y=0.0254/1000 #m
# Delta_mu=6.4 #m/s
# a=0.64 #m/s2
#
# A= 2*pi*(d/2)*h #m2
# m= W/g #kg
#
# mu= ((m*a+W)/(A*Delta_mu))*Delta_y #N.s/m2

# %% [markdown]
# ---
# #### Question 7 (***)

# %% [markdown]
# A journal bearing consists of an 80.0 mm diameter shaft in an 80.4 mm sleeve 120 mm long. The clearance space is filled with oil with a viscosity of 0.11 N.s/m<sup>2</sup>. Calculate the torque required to keep the shaft turning at 150 rpm.

# %% [markdown]
# ```{dropdown} Answer
#
# $0.417 \; N.m$
# ```

# %% [markdown]
# ```{dropdown} Hint
# The torque is calculated by multiplying the force with the distance
#
# $$
# T= F \cdot r_{shaft}\\
# $$
#
# where the force can be calculated from viscosity.
#
# [Click here for a video explaining the problem](https://auckland.au.panopto.com/Panopto/Pages/Viewer.aspx?id=ef2dfea1-f7b0-40d9-9b20-b29d01756b86)
#
# ```

# %%
from PIL import Image
img = Image.open(r"figures/4_viscosity_7.png")
base_width = 350 # Change this to your desired width
w_percent = base_width / float(img.size[0])
h_size = int(float(img.size[1]) * w_percent)
resized_img = img.resize((base_width, h_size))
resized_img

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
#
# Torque:
#
# $$
# T= F \cdot r_{shaft}\\
# $$
#
# With:
#
# $$
# F=\tau A\\
# $$
#
# and
#
# $$
# \tau= \mu\frac {\Delta u}{\Delta y}
# $$
#
# Assuming linear velocity distribution
#
# $$
# u= wr
# $$
#
# $$
# w= \frac {2 \pi N}{60}
# $$
#
# $$
# u=\frac{r_{shaft}\cdot2\cdot\pi\cdot N_{rpm}}{60}
# $$
#
# ```

# %%
# %%render long 4
# d_shaft= 80/1000 #m
# d_sleeve= 80.4/1000 #m
# L_shaft= 120/1000 #m
# mu=0.11 #Ns/m2
# N_rpm=150 #rpm
#
# r_shaft= (d_shaft)/2 #m
#
# u= (r_shaft*2*pi*N_rpm)/60 #m/s
#
# Delta_y= ((d_sleeve-d_shaft))/2 #m
#
# tau= mu*u/Delta_y #Pa
#
# F= tau*pi*(d_shaft)*(L_shaft) #N
#
# T= F*r_shaft #N.m
